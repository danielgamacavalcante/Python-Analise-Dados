# %% [markdown]
# # ETL DATASUS - Dados de Suicídios
#
# *Fonte: Datasus*
#
# *Site:Kaggle*
#
# Foco: Carregar, inspecionar, tratar valores ausentes simples, corrigir tipos de dados e carregar no banco de dados `Postgres`.
#
# **Contexto do projeto**: Nosso objetivo é limpar e preparar uma base de dados relacionados a suicídios para criar um relatório demográfico.

# %% [markdown]
# ## Passo 1: Configurando o ambiente

# %%
# Instalar as ferramentas necessárias para trabalhar com dados do tipo .csv e banco de dados
# %pip install pandas sqlalchemy psycopg2-binary -q
# %pip install sqlalchemy-utils -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importando Bibliotecas

import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists,create_database
import psycopg2

#ignora avisos de atenção
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Passo 2: E (Extract) - Extração de Dados

# %%
#carregando base de dados Datasus
df_datasus = pd.read_csv('base-dados/datasus_suicidio_2014_2018.csv',encoding='Windows-1252',sep=',')

#usamos o display() no lugar do print() para uma melhor visualização do DataFrame
display(df_datasus.head())
# Out:
#   estado   ano CIRCOBITO   DTOBITO    DTNASC       SEXO RACACOR  \
# 0     AC  2014  Suicídio  02-01-14  02-07-77  Masculino   Preta
# 1     AC  2014  Suicídio  23-01-14  30-07-66  Masculino  Branca
# 2     AC  2014  Suicídio  31-01-14  28-07-43  Masculino  Branca
# 3     AC  2014  Suicídio  05-02-14  04-07-99  Masculino  Branca
# 4     AC  2014  Suicídio  06-02-14  02-05-72  Masculino  Branca
#
#              ESTCIV         ESC                             OCUP  \
# 0            Casado  4 a 7 anos   ATLETA PROFISSIONAL DE FUTEBOL
# 1  União consensual   12 e mais  MEDICO GINECOLOGISTA E OBSTETRA
# 2               NaN         NaN                                0
# 3          Solteiro  4 a 7 anos                        ESTUDANTE
# 4               NaN         NaN                                0
#
#         CODMUNRES    LOCOCOR ASSISTMED CAUSABAS CAUSABAS_O  idade  mes
# 0      Rio Branco  Domicílio       Não     X700       X700   37.0    1
# 1      Rio Branco  Domicílio       Não     X800       X800   48.0    1
# 2      Rio Branco  Domicílio       Não     X700       X700   71.0    1
# 3  Epitaciolândia     Outros       Não     X700       X700   15.0    2
# 4      Rio Branco     Outros       Não     X700       X700   42.0    2

# %%
print(f'Número de linhas e colunas: {df_datasus.shape}')
# print('\n' + '='*50 +'\n')
print("\nVamos ver as informações gerais e os tipos de dados de cada coluna:\n")
df_datasus.info()
# Out:
# Número de linhas e colunas: (58634, 17)
#
# Vamos ver as informações gerais e os tipos de dados de cada coluna:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58634 entries, 0 to 58633
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   estado      58634 non-null  object
#  1   ano         58634 non-null  int64
#  2   CIRCOBITO   56606 non-null  object
#  3   DTOBITO     58634 non-null  object
#  4   DTNASC      58407 non-null  object
#  5   SEXO        58619 non-null  object
#  6   RACACOR     57298 non-null  object
#  7   ESTCIV      54305 non-null  object
#  8   ESC         45162 non-null  object
#  9   OCUP        58634 non-null  object
#  10  CODMUNRES   58634 non-null  object
#  11  LOCOCOR     58463 non-null  object
#  12  ASSISTMED   40872 non-null  object
#  13  CAUSABAS    58634 non-null  object
#  14  CAUSABAS_O  58544 non-null  object
#  15  idade       58407 non-null  float64
#  16  mes         58634 non-null  int64
# dtypes: float64(1), int64(2), object(14)
# memory usage: 7.6+ MB

# %% [markdown]
# ## Passo 3: T (Transform) - Transformação dos Dados

# %%
print(f'\nEstatísticas dos atributos do tipo númerico:\n {df_datasus.describe()}')
# Out:
# Estatísticas dos atributos do tipo númerico:
#                  ano         idade           mes
# count  58634.000000  58407.000000  58634.000000
# mean    2016.093325     42.543308      6.585496
# std        1.412665     17.378526      3.502479
# min     2014.000000      0.000000      1.000000
# 25%     2015.000000     29.000000      3.000000
# 50%     2016.000000     40.000000      7.000000
# 75%     2017.000000     54.000000     10.000000
# max     2018.000000    113.000000     12.000000

# %%
display(df_datasus.sample(20))
# Out:
#       estado   ano CIRCOBITO   DTOBITO    DTNASC       SEXO RACACOR  \
# 22965     CE  2016  Suicídio  06-04-16  25-12-45   Feminino  Branca
# 9737      SP  2014  Suicídio  09-09-14  29-10-75  Masculino   Parda
# 23233     CE  2016  Suicídio  26-09-16  26-06-63  Masculino  Branca
# 14450     MG  2015  Suicídio  17-03-15  02-04-65  Masculino     NaN
# 50565     MG  2018  Suicídio  21-09-18  11-10-72  Masculino   Parda
# 19269     SC  2015  Suicídio  09-12-15  30-12-39  Masculino  Branca
# 1135      CE  2014  Suicídio  16-06-14  08-12-86  Masculino     NaN
# 3911      MG  2014  Suicídio  16-10-14  17-06-73  Masculino  Branca
# 26337     PA  2016  Suicídio  11-06-16  20-11-98  Masculino   Parda
# 9009      SP  2014  Suicídio  03-05-14  20-05-52  Masculino  Branca
# 31377     SP  2016  Suicídio  14-03-16  24-08-70   Feminino  Branca
# 7081      RS  2014  Suicídio  23-07-14  01-06-83  Masculino  Branca
# 28521     RJ  2016  Suicídio  27-08-16  18-05-66   Feminino  Branca
# 11324     BA  2015  Suicídio  02-02-15  18-12-72  Masculino   Preta
# 23604     ES  2016  Suicídio  28-03-16  01-01-74  Masculino   Parda
# 43306     SC  2017  Suicídio  10-10-17  05-10-59  Masculino  Branca
# 14513     MG  2015  Suicídio  06-05-15  27-02-85  Masculino   Parda
# 6628      RS  2014  Suicídio  20-02-14  23-11-83  Masculino  Branca
# 19718     SP  2015  Suicídio  30-05-15  19-09-46   Feminino  Branca
# 52725     PE  2018       NaN  28-09-18  27-04-98   Feminino   Parda
#
#                        ESTCIV          ESC                               OCUP  \
# 22965                Solteiro   1 a 3 anos      PRODUTOR AGRICOLA POLIVALENTE
# 9737                 Solteiro  8 a 11 anos                                  0
# 23233                  Casado  8 a 11 anos                                  0
# 14450                     NaN          NaN                                  0
# 50565  Separado judicialmente          NaN             GERENTE ADMINISTRATIVO
# 19269                  Casado      Nenhuma                                  0
# 1135                 Solteiro   1 a 3 anos  AUXILIAR DE PRODUCAO FARMACEUTICA
# 3911                 Solteiro   1 a 3 anos              DESEMPREGADO CRONICO
# 26337                Solteiro   4 a 7 anos                                  0
# 9009                   Casado  8 a 11 anos                    PINTOR DE OBRAS
# 31377                Solteiro    12 e mais                          SOCIOLOGO
# 7081                 Solteiro   4 a 7 anos                           GESSEIRO
# 28521                Solteiro    12 e mais                    DIRETOR TEATRAL
# 11324                Solteiro   4 a 7 anos                           PEDREIRO
# 23604                  Casado          NaN                                  0
# 43306                  Casado  8 a 11 anos    PRODUTOR AGROPECUARIO, EM GERAL
# 14513                  Casado          NaN                                  0
# 6628                 Solteiro          NaN                                  0
# 19718                Solteiro   1 a 3 anos             APOSENTADO/PENSIONISTA
# 52725                Solteiro   4 a 7 anos              DESEMPREGADO CRONICO
#
#              CODMUNRES    LOCOCOR ASSISTMED CAUSABAS CAUSABAS_O  idade  mes
# 22965       Alto Santo  Domicílio       NaN     X709       X709   71.0    4
# 9737           Diadema  Domicílio       Não     X740       X740   39.0    9
# 23233       Boa Viagem     Outros       Não     X709       X709   53.0    9
# 14450         Joanésia  Domicílio       Não     X700       X700   50.0    3
# 50565      Sete Lagoas     Outros       Não     X700       X700   46.0    9
# 19269          Tijucas  Domicílio       Não     X700       X700   76.0   12
# 1135         Fortaleza     Outros       Não     X708       X708   28.0    6
# 3911   Poços de Caldas     Outros       Não     X709       X709   41.0   10
# 26337            Belém  Domicílio       Não     X700       X700   18.0    6
# 9009            Osasco  Domicílio       NaN     X700       X700   62.0    5
# 31377            Cotia  Domicílio       Não     X700       X700   46.0    3
# 7081          Alvorada  Domicílio       NaN     X700       X700   31.0    7
# 28521   Rio de Janeiro  Domicílio       NaN     X709       Y200   50.0    8
# 11324         Salvador   Hospital       Sim     X689        R99   43.0    2
# 23604            Serra     Outros       Não     X718        R99   42.0    3
# 43306  Anita Garibaldi     Outros       Não     X709       X709   58.0   10
# 14513    Monte Carmelo   Hospital       Sim     X619        R99   30.0    5
# 6628             Ivoti  Domicílio       Sim     X700       X700   31.0    2
# 19718        São Paulo     Outros       NaN     X800       Y299   69.0    5
# 52725        Arcoverde     Outros       Não     X700       X700   20.0    9

# %%
#Aplicar o describer para ver as estatísticas dos atributos do tipo texto
print('\nEstatísticas descritivas dos atributos do tipo texto:\n')
df_datasus.describe(include='object')
# Out:
# Estatísticas descritivas dos atributos do tipo texto:
#        estado CIRCOBITO   DTOBITO    DTNASC       SEXO RACACOR    ESTCIV  \
# count   58634     56606     58634     58407      58619   57298     54305
# unique     27         4      1826     22200          2       5         5
# top        SP  Suicídio  01-01-17  15-06-81  Masculino  Branca  Solteiro
# freq    11256     55484        64        12      46169   29193     29408
#
#                 ESC   OCUP  CODMUNRES    LOCOCOR ASSISTMED CAUSABAS CAUSABAS_O
# count         45162  58634      58634      58463     40872    58634      58544
# unique            5   1108       4769          6         2      301        527
# top     8 a 11 anos      0  São Paulo  Domicílio       Não     X700       X700
# freq          14503  12353       2090      36070     32629    28997      26666

# %% [markdown]
# ### 3.1 Selecionar Colunas Relevantes

# %%
print('\n Colunas disponíveis no DataFrame:')
df_datasus.columns
# Out:
#  Colunas disponíveis no DataFrame:
# Index(['estado', 'ano', 'CIRCOBITO', 'DTOBITO', 'DTNASC', 'SEXO', 'RACACOR',
#        'ESTCIV', 'ESC', 'OCUP', 'CODMUNRES', 'LOCOCOR', 'ASSISTMED',
#        'CAUSABAS', 'CAUSABAS_O', 'idade', 'mes'],
#       dtype='object')

# %%
# Selecionando colunas relevantes
colunas_selecionadas = [
    'DTOBITO',
    'DTNASC', 
    'SEXO', 
    'RACACOR',
    'ESTCIV', 
    'ESC', 
    'OCUP',
    'LOCOCOR',
    'idade'
]
print(f'\nColunas selecionadas:\n {colunas_selecionadas}')

df_datasus_selecionados = df_datasus[colunas_selecionadas]
display(df_datasus_selecionados.head())
# Out:
# Colunas selecionadas:
#  ['DTOBITO', 'DTNASC', 'SEXO', 'RACACOR', 'ESTCIV', 'ESC', 'OCUP', 'LOCOCOR', 'idade']
#     DTOBITO    DTNASC       SEXO RACACOR            ESTCIV         ESC  \
# 0  02-01-14  02-07-77  Masculino   Preta            Casado  4 a 7 anos
# 1  23-01-14  30-07-66  Masculino  Branca  União consensual   12 e mais
# 2  31-01-14  28-07-43  Masculino  Branca               NaN         NaN
# 3  05-02-14  04-07-99  Masculino  Branca          Solteiro  4 a 7 anos
# 4  06-02-14  02-05-72  Masculino  Branca               NaN         NaN
#
#                               OCUP    LOCOCOR  idade
# 0   ATLETA PROFISSIONAL DE FUTEBOL  Domicílio   37.0
# 1  MEDICO GINECOLOGISTA E OBSTETRA  Domicílio   48.0
# 2                                0  Domicílio   71.0
# 3                        ESTUDANTE     Outros   15.0
# 4                                0     Outros   42.0

# %% [markdown]
# ### 3.2 Tratamento do dtype (tipo de dados)
# Vamos tratar os dtype dos campos do tipo data e valores ausentes

# %%
# Veridicando os valores ausentes do Dataframe:
print('\nValores ausentes (null) em cada coluna:\n')
df_datasus.isnull().sum()
# Out:
# Valores ausentes (null) em cada coluna:
# estado            0
# ano               0
# CIRCOBITO      2028
# DTOBITO           0
# DTNASC          227
# SEXO             15
# RACACOR        1336
# ESTCIV         4329
# ESC           13472
# OCUP              0
# CODMUNRES         0
# LOCOCOR         171
# ASSISTMED     17762
# CAUSABAS          0
# CAUSABAS_O       90
# idade           227
# mes               0
# dtype: int64

# %%
df_datasus_selecionados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58634 entries, 0 to 58633
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DTOBITO  58634 non-null  object
#  1   DTNASC   58407 non-null  object
#  2   SEXO     58619 non-null  object
#  3   RACACOR  57298 non-null  object
#  4   ESTCIV   54305 non-null  object
#  5   ESC      45162 non-null  object
#  6   OCUP     58634 non-null  object
#  7   LOCOCOR  58463 non-null  object
#  8   idade    58407 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 4.0+ MB

# %%
# Convertrr para o tipo datatime as colunas de data

#Transformando a coluna DTOBITO para o tipo DateTime
df_datasus_selecionados['DTOBITO'] = pd.to_datetime(df_datasus_selecionados['DTOBITO'])

#Transformando a coluna DTNASC para o tipo DateTime
df_datasus_selecionados['DTNASC'] = pd.to_datetime(df_datasus_selecionados['DTNASC'])

# %%
# excluindo as linhas com valores ausentes
df_datasus_selecionados = df_datasus_selecionados.dropna(subset=['DTNASC'])

# %%
df_datasus_selecionados.isnull().sum()
# Out:
# DTOBITO        0
# DTNASC         0
# SEXO           3
# RACACOR     1295
# ESTCIV      4144
# ESC        13274
# OCUP           0
# LOCOCOR      163
# idade          0
# dtype: int64

# %%
#Contando os valores da coluna Sexo considerando NaN também
df_datasus_selecionados['SEXO'].value_counts(dropna=False)
# Out:
# SEXO
# Masculino        45981
# Feminino         12423
# Não Informado        3
# Name: count, dtype: int64

# %%
#Tratando o campo de sexo
df_datasus_selecionados['SEXO'].fillna('Não Informado', inplace=True)

# %%
# substituindo os valores ausentes (NaN) para 'Não Informado'
df_datasus_selecionados['RACACOR'].fillna('Não Informado', inplace=True)
df_datasus_selecionados['ESTCIV'].fillna('Não Informado', inplace=True)
df_datasus_selecionados['ESC'].fillna('Não Informado', inplace=True)
df_datasus_selecionados['LOCOCOR'].fillna('Não Informado', inplace=True)

df_datasus_selecionados.isnull().sum()
# Out:
# DTOBITO    0
# DTNASC     0
# SEXO       0
# RACACOR    0
# ESTCIV     0
# ESC        0
# OCUP       0
# LOCOCOR    0
# idade      0
# dtype: int64

# %% [markdown]
# ### 3.3 Renomeando as Colunas

# %%
df_datasus_selecionados.head()
# Out:
#      DTOBITO     DTNASC       SEXO RACACOR            ESTCIV            ESC  \
# 0 2014-02-01 1977-02-07  Masculino   Preta            Casado     4 a 7 anos
# 1 2014-01-23 2066-07-30  Masculino  Branca  União consensual      12 e mais
# 2 2014-01-31 2043-07-28  Masculino  Branca     Não Informado  Não Informado
# 3 2014-05-02 1999-04-07  Masculino  Branca          Solteiro     4 a 7 anos
# 4 2014-06-02 2072-02-05  Masculino  Branca     Não Informado  Não Informado
#
#                               OCUP    LOCOCOR  idade
# 0   ATLETA PROFISSIONAL DE FUTEBOL  Domicílio   37.0
# 1  MEDICO GINECOLOGISTA E OBSTETRA  Domicílio   48.0
# 2                                0  Domicílio   71.0
# 3                        ESTUDANTE     Outros   15.0
# 4                                0     Outros   42.0

# %%
df_datasus_selecionados.rename(columns={
    'DTOBITO':'data_obito',
    'DTNASC':'data_nascimento',
    'SEXO': 'sexo',
    'RACACOR':'raca_cor',
    'ESTCIV': 'estado_civil',
    'ESC': 'escolaridade',
    'OCUP':'ocupacao',
    'LOCOCOR': 'local_ocorrencia'
}, inplace=True)

df_datasus_selecionados.head()
# Out:
#   data_obito data_nascimento       sexo raca_cor      estado_civil  \
# 0 2014-02-01      1977-02-07  Masculino    Preta            Casado
# 1 2014-01-23      2066-07-30  Masculino   Branca  União consensual
# 2 2014-01-31      2043-07-28  Masculino   Branca     Não Informado
# 3 2014-05-02      1999-04-07  Masculino   Branca          Solteiro
# 4 2014-06-02      2072-02-05  Masculino   Branca     Não Informado
#
#     escolaridade                         ocupacao local_ocorrencia  idade
# 0     4 a 7 anos   ATLETA PROFISSIONAL DE FUTEBOL        Domicílio   37.0
# 1      12 e mais  MEDICO GINECOLOGISTA E OBSTETRA        Domicílio   48.0
# 2  Não Informado                                0        Domicílio   71.0
# 3     4 a 7 anos                        ESTUDANTE           Outros   15.0
# 4  Não Informado                                0           Outros   42.0

# %%
df_datasus_selecionados.to_csv('arquivo_tratado.csv', index=False)

# %% [markdown]
# # Passo 4: L (LOAD) - Carregamento no banco de dados
